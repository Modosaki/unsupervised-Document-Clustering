# %%
import glob

# %%
from os.path import basename, splitext
import pandas as pd

# %%
import numpy as np
import os
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
from os.path import basename, splitext
import pandas as pd


res = pd.DataFrame()
for file_ in glob.glob(r'C:\Users\k\Desktop\project3\riskdocs1000\*.txt'):
    with open(file_) as f:
        textf = " ".join(line.strip() for line in f)
    res = pd.concat([res,pd.DataFrame(data = {"filename" : [splitext(basename(file_))[0]], "Riskfactors" : [textf]})])

# %%
res.reindex()
riskdf=res.reset_index()

# %%
riskdf
# Out:
#      index                           filename  \
# 0        0           180 Degree Capital Corp
# 1        0             3D Systems Corporation
# 2        0                         3M Company
# 3        0               A H Belo Corporation
# 4        0                  A10 Networks Inc
# 5        0                  AAC Holdings Inc
# 6        0                Abbott Laboratories
# 7        0                        AbbVie Inc
# 8        0        ABM Industries Incorporated
# 9        0     Acadia Healthcare Company Inc
# 10       0        ACADIA Pharmaceuticals Inc
# 11       0                Acadia Realty Trust
# 12       0        Accelerate Diagnostics Inc
# 13       0                      Accenture plc
# 14       0                      Achaogen Inc
# 15       0           Acme United Corporation
# 16       0            Activision Blizzard Inc
# 17       0                Actuant Corporation
# 18       0                  Acuity Brands Inc
# 19       0        Adamas Pharmaceuticals Inc
# 20       0                        ADTRAN Inc
# 21       0             Advance Auto Parts Inc
# 22       0        Advanced Micro Devices Inc
# 23       0             AdvisorShares Vice ETF
# 24       0             Aerohive Networks Inc
# 25       0   Aerojet Rocketdyne Holdings Inc
# 26       0                 AeroVironment Inc
# 27       0                         Aetna Inc
# 28       0         Aevi Genomic Medicine Inc
# 29       0                 Aflac Incorporated
# ..     ...                                ...
# 970      0      Quintana Energy Services Inc
# 971      0          Quorum Health Corporation
# 972      0                   Quotient Limited
# 973      0           Quotient Technology Inc
# 974      0         R R Donnelley Sons Company
# 975      0                        R1 RCM Inc
# 976      0             Radiant Logistics Inc
# 977      0           Ralph Lauren Corporation
# 978      0                        Rambus Inc
# 979      0                        Rapid7 Inc
# 980      0       Raymond James Financial Inc
# 981      0   Rayonier Advanced Materials Inc
# 982      0                   Raytheon Company
# 983      0          Ready Capital Corporation
# 984      0             Realogy Holdings Corp
# 985      0          Realty Income Corporation
# 986      0                  Recro Pharma Inc
# 987      0                       Red Hat Inc
# 988      0        Red Lion Hotels Corporation
# 989      0     Regeneron Pharmaceuticals Inc
# 990      0                     REGENXBIO Inc
# 991      0          Regulus Therapeutics Inc
# 992      0                 Rent A Center Inc
# 993      0               Repligen Corporation
# 994      0              Republic Bancorp Inc
# 995      0          ReShape Lifesciences Inc
# 996      0        Resolute Energy Corporation
# 997      0                      Resonant Inc
# 998      0                     resTORbio Inc
# 999      0  Retail Properties of America Inc
#
#                                            Riskfactors
# 0    [1] "Item 1A.    Risk Factors.. Investing in o...
# 1    [1] "Item 1A. Risk Factors. <U+FEFF>. The risk...
# 2    [1] "Item 1A. Risk Factors.. Provided below is...
# 3    [1] "Item 1A. Risk Factors. The following risk...
# 4    [1] "ITEM 1A. RISK FACTORS. Investing in our c...
# 5    [1] "Item 1A. Risk Factors. Our actual operati...
# 6    [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 7    [1] "ITEM 1A. RISK FACTORS. You should careful...
# 8    [1] "ITEM 1A. RISK FACTORS.. We may not realiz...
# 9    [1] "Item  1A. Risk Factors. Any of the follow...
# 10   [1] "Item 1A.  Risk Factors.. You should consi...
# 11   [1] "ITEM 1A. RISK FACTORS.. Set forth below a...
# 12   [1] "Item 1A.  Risk Factors. Investing in our ...
# 13   [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 14   [1] "Item 1A. Risk Factors.. Risks Related to ...
# 15   [1] "Item 1A. Risk Factors. The Company is sub...
# 16   [1] "Item 1A.    RISK FACTORS. We wish to caut...
# 17   [1] "Item  1A.    Risk Factors. The risks and ...
# 18   [1] "Item 1a. Risk Factors. This filing contai...
# 19   [1] "Item 1A.  Risk Factors. We have identifie...
# 20   [1] "ITEM 1A.  RISK FACTORS. The Private Secur...
# 21   [1] "Item 1A. Risk Factors.. Our business is s...
# 22   [1] "ITEM 1A. RISK FACTORS. The risks and unce...
# 23   [1] "ITEM 1A. RISK FACTORS. CAUTIONARY NOTE RE...
# 24   [1] "ITEM 1A.    RISK FACTORS. In evaluating A...
# 25   [1] "Item 1A.  Risk Factors. Future reductions...
# 26   [1] "Item 1A.  Risk Factors.. General Business...
# 27   [1] "Item 1A.  Risk Factors. Risk Factors. You...
# 28   [1] "ITEM 1A - Risk Factors.. Business-Related...
# 29   [1] "ITEM 1A. RISK FACTORS. The Company faces ...
# ..                                                 ...
# 970  [1] "Item 1A. Risk Factors. Investing in our c...
# 971  [1] "Item 1A.Risk Factors. Our company faces a...
# 972  [1] "Item 1A. Risk Factors. Risks Related to O...
# 973  [1] "Item 1A.  Risk Factors.. Our operations a...
# 974  [1] "ITEM  1A.  RISK FACTORS. Our consolidated...
# 975  [1] "Item 1A. Risk Factors. Risks Relating to ...
# 976  [1] "ITEM 1A. RISK FACTORS. RISKS PARTICULAR T...
# 977  [1] "Item 1A. Risk Factors. There are risks as...
# 978  [1] "Item 1A. Risk Factors. RISK FACTORS. Beca...
# 979  [1] "Item 1A. Risk Factors.. Our operations an...
# 980  [1] "Item 1A.  RISK FACTORS. Our operations an...
# 981  [1] "Item 1A. Risk Factors. Our operations are...
# 982  [1] "ITEM 1A. RISK FACTORS. This Form 10-K and...
# 983  [1] "Item 1A. Risk Factors. Our business and o...
# 984  [1] "Item 1A.    Risk Factors.. You should car...
# 985  [1] "Item 1A:      Risk Factors. This \"Risk F...
# 986  [1] "Item 1A.  Risk Factors. The following ris...
# 987  [1] "ITEM 1A. RISK FACTORS. Set forth below ar...
# 988  [1] "Item 1A. Risk Factors. We are subject to ...
# 989  [1] "ITEM 1A.  RISK FACTORS. We operate in an ...
# 990  [1] "ITEM 1A.  RISK FACTORS. You should carefu...
# 991  [1] "Item 1A. Risk Factors. You should conside...
# 992  [1] "Item 1A.    Risk Factors.. You should car...
# 993  [1] "ITEM 1A. RISK FACTORS. Investors should c...
# 994  [1] "Item 1A.  Risk Factors.. FACTORS THAT MAY...
# 995  [1] "ITEM 1A.  RISK FACTORS. Risks Related to ...
# 996  [1] "ITEM 1A.  RISK FACTORS. You should consid...
# 997  [1] "ITEM 1A.               RISK FACTORS. Inve...
# 998  [1] "Item 1A. Risk Factors.. Investing in our ...
# 999  [1] "ITEM 1A. RISK FACTORS. In evaluating our ...
#
# [1000 rows x 3 columns]

# %%
df_ticker = pd.read_csv('secwiki_tickers.csv')
df_ticker.head()
# Out:
#   Ticker                       Name            Sector  \
# 0      A  Agilent Technologies Inc.        Healthcare
# 1     AA                 Alcoa Inc.   Basic Materials
# 2   AAME    Atlantic American Corp.         Financial
# 3    AAN              Aaron's, Inc.          Services
# 4   AAON                  AAON Inc.  Industrial Goods
#
#                           Industry      Price   Collection
# 0  Medical Laboratories & Research     WIKI/A     stocks/a
# 1                         Aluminum    WIKI/AA    stocks/aa
# 2                   Life Insurance        NaN  stocks/aame
# 3        Rental & Leasing Services   WIKI/AAN   stocks/aan
# 4       General Building Materials  WIKI/AAON  stocks/aaon

# %%
# Out:
#    index                       filename  \
# 0      0       180 Degree Capital Corp
# 1      0  3D Systems Corporation - Copy
# 2      0         3D Systems Corporation
# 3      0                     3M Company
# 4      0           A H Belo Corporation
#
#                                          Riskfactors
# 0  [1] "Item 1A.    Risk Factors.. Investing in o...
# 1  [1] "Item 1A. Risk Factors. <U+FEFF>. The risk...
# 2  [1] "Item 1A. Risk Factors. <U+FEFF>. The risk...
# 3  [1] "Item 1A. Risk Factors.. Provided below is...
# 4  [1] "Item 1A. Risk Factors. The following risk...

# %%
# Out:
#    index                       filename  \
# 0      0       180 Degree Capital Corp
# 1      0  3D Systems Corporation - Copy
# 2      0         3D Systems Corporation
# 3      0                     3M Company
# 4      0           A H Belo Corporation
#
#                                          Riskfactors
# 0  [1] "Item 1A.    Risk Factors.. Investing in o...
# 1  [1] "Item 1A. Risk Factors. <U+FEFF>. The risk...
# 2  [1] "Item 1A. Risk Factors. <U+FEFF>. The risk...
# 3  [1] "Item 1A. Risk Factors.. Provided below is...
# 4  [1] "Item 1A. Risk Factors. The following risk...

# %%
riskdf.to_csv("output.csv", index=True)

# %%
c=riskdf.filename
print(c[0])
# Out:
# 180 Degree Capital Corp

# %%
pTickers = riskdf.filename  # converts into a list
prisk=riskdf.Riskfactors

Ticker=[]
Cname=[]
Crisk=[]
tmpTickers = []

for i in range(len(pTickers)):
    test = df_ticker[df_ticker.Name==pTickers[i]]
    if not (test.empty):
        print("%-10s%s" % (list(test.Ticker.values)[0], pTickers[i] ))
        tmpTickers.append("%-10s%s" % (list(test.Ticker.values)[0], pTickers[i] ))
        Ticker.append(list(test.Ticker.values)[0])
        Cname.append(pTickers[i])
        Crisk.append(prisk[i])
        x=pTickers[i]
        y=list(test.Ticker.values)[0]
        z=prisk[i]
        
Cticker = dict(zip(Ticker, zip(Cname, Crisk)))
# Out:
# MMM       3M Company
# ABT       Abbott Laboratories
# ABM       ABM Industries Incorporated
# AKR       Acadia Realty Trust
# ACN       Accenture plc
# ATU       Actuant Corporation
# ALB       Albemarle Corporation
# LNT       Alliant Energy Corporation
# AEE       Ameren Corporation
# AMS       American Shared Hospital Services
# ATLO      Ames National Corporation
# APH       Amphenol Corporation
# AXR       AMREP Corporation
# ANCB      Anchor Bancorp
# ANH       Anworth Mortgage Asset Corporation
# ADM       Archer Daniels Midland Company
# ACRE      Ares Commercial Real Estate Corporation
# ATRO      Astronics Corporation
# ATLC      Atlanticus Holdings Corporation
# ATO       Atmos Energy Corporation
# BOH       Bank of Hawaii Corporation
# BANR      Banner Corporation
# BBOX      Black Box Corporation
# BOKF      BOK Financial Corporation
# BAH       Booz Allen Hamilton Holding Corporation
# BRKR      Bruker Corporation
# CPT       Camden Property Trust
# CPB       Campbell Soup Company
# CPHC      Canterbury Park Holding Corporation
# COF       Capital One Financial Corporation
# CCL       Carnival Corporation
# CBS       CBS Corporation
# CELG      Celgene Corporation
# CVCY      Central Valley Community Bancorp
# CERS      Cerus Corporation
# ECOM      ChannelAdvisor Corporation
# CCF       Chase Corporation
# CHSP      Chesapeake Lodging Trust
# CTAS      Cintas Corporation
# CIZN      Citizens Holding Company
# CLW       Clearwater Paper Corporation
# CFX       Colfax Corporation
# COLM      Columbia Sportswear Company
# CMCO      Columbus McKinnon Corporation
# CNMD      CONMED Corporation
# COP       ConocoPhillips
# CORT      Corcept Therapeutics Incorporated
# COR       CoreSite Realty Corporation
# COST      Costco Wholesale Corporation
# CPAH      CounterPath Corporation
# CVA       Covanta Holding Corporation
# CUB       Cubic Corporation
# CY        Cypress Semiconductor Corporation
# DWCH      Datawatch Corporation
# DWSN      Dawson Geophysical Company
# DEST      Destination Maternity Corporation
# DRAD      Digirad Corporation
# DIOD      Diodes Incorporated
# DG        Dollar General Corporation
# DRE       Duke Realty Corporation
# EDUC      Educational Development Corporation
# EGAN      eGain Corporation
# EFC       Ellington Financial LLC
# ESGR      Enstar Group Limited
# EVC       Entravision Communications Corporation
# ERIE      Erie Indemnity Company
# EXAS      Exact Sciences Corporation
# FAST      Fastenal Company
# LION      Fidelity Southern Corporation
# BUSE      First Busey Corporation
# FUNC      First United Corporation
# GPIC      Gaming Partners International Corporation
# GM        General Motors Company
# G         Genpact Limited
# GPC       Genuine Parts Company
# GHM       Graham Corporation
# GFF       Griffon Corporation
# GBNK      Guaranty Bancorp
# HNRG      Hallador Energy Company
# HRS       Harris Corporation
# HSC       Harsco Corporation
# HSKA      Heska Corporation
# HPT       Hospitality Properties Trust
# IMMR      Immersion Corporation
# IBCP      Independent Bank Corporation
# IART      Integra LifeSciences Holdings Corporation
# IBM       International Business Machines Corporation
# IRET      Investors Real Estate Trust
# IPGP      IPG Photonics Corporation
# IRBT      iRobot Corporation
# LRCX      Lam Research Corporation
# LANC      Lancaster Colony Corporation
# LRY       Liberty Property Trust
# LGND      Ligand Pharmaceuticals Incorporated
# LNC       Lincoln National Corporation
# LMNX      Luminex Corporation
# LYB       LyondellBasell Industries NV
# MRIN      Marin Software Incorporated
# MAS       Masco Corporation
# MTRN      Materion Corporation
# MTRX      Matrix Service Company
# MGM       MGM Resorts International
# TAP       Molson Coors Brewing Company
# NANO      Nanometrics Incorporated
# NAV       Navistar International Corporation
# NPTN      NeoPhotonics Corporation
# NEU       NewMarket Corporation
# ORCL      Oracle Corporation
# PACW      PacWest Bancorp
# PAR       PAR Technology Corporation
# PVA       Penn Virginia Corporation
# PEI       Pennsylvania Real Estate Investment Trust
# PNW       Pinnacle West Capital Corporation
# PLPC      Preformed Line Products Company
# PRMW      Primo Water Corporation
# PRIM      Primoris Services Corporation
# PRA       ProAssurance Corporation
# PRGS      Progress Software Corporation
# RL        Ralph Lauren Corporation
# O         Realty Income Corporation
# RLH       Red Lion Hotels Corporation
# RGEN      Repligen Corporation
# REN       Resolute Energy Corporation

# %%
companyTicker=pd.DataFrame.from_dict(Cticker, orient='index')
ct_df=companyTicker.reset_index()
ct_df.head()
# Out:
#   index                            0  \
# 0   MMM                   3M Company
# 1   ABT          Abbott Laboratories
# 2   ABM  ABM Industries Incorporated
# 3   AKR          Acadia Realty Trust
# 4   ACN                Accenture plc
#
#                                                    1
# 0  [1] "Item 1A. Risk Factors.. Provided below is...
# 1  [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 2  [1] "ITEM 1A. RISK FACTORS.. We may not realiz...
# 3  [1] "ITEM 1A. RISK FACTORS.. Set forth below a...
# 4  [1] "ITEM 1A.    RISK FACTORS. In addition to ...

# %%
# output = pd.merge(df1, df2, how="inner", on="created_at") #column_name should be common in both dataframe. how represents type of intersection. In your case it will be inner(INNER JOIN)

# df4 = output.created_at.value_counts().rename_axis('created_at').reset_index(name='adam3us_tweets')

# df4 = df4.sort_values(by=['created_at'])
# ct_df.columns

# %%
ct_df.rename(columns={'index':'ticker'}, inplace=True)
ct_df.rename(columns={0:'ticer'}, inplace=True)
ct_df.rename(columns={1:'risk'}, inplace=True)
ct_df.head()
# Out:
#   companyName                       ticker  \
# 0         MMM                   3M Company
# 1         ABT          Abbott Laboratories
# 2         ABM  ABM Industries Incorporated
# 3         AKR          Acadia Realty Trust
# 4         ACN                Accenture plc
#
#                                                 risk
# 0  [1] "Item 1A. Risk Factors.. Provided below is...
# 1  [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 2  [1] "ITEM 1A. RISK FACTORS.. We may not realiz...
# 3  [1] "ITEM 1A. RISK FACTORS.. Set forth below a...
# 4  [1] "ITEM 1A.    RISK FACTORS. In addition to ...

# %%
ct_df.iloc[2]['ticker']
# Out:
# 'ABM Industries Incorporated'

# %%
ct_df.head()
# Out:
#   companyName                       ticker  \
# 0         MMM                   3M Company
# 1         ABT          Abbott Laboratories
# 2         ABM  ABM Industries Incorporated
# 3         AKR          Acadia Realty Trust
# 4         ACN                Accenture plc
#
#                                                 risk
# 0  [1] "Item 1A. Risk Factors.. Provided below is...
# 1  [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 2  [1] "ITEM 1A. RISK FACTORS.. We may not realiz...
# 3  [1] "ITEM 1A. RISK FACTORS.. Set forth below a...
# 4  [1] "ITEM 1A.    RISK FACTORS. In addition to ...

# %%
# documents = [res.iloc[0]['Riskfactors'],res.iloc[1]['Riskfactors'],res.iloc[2]['Riskfactors']]

documents=[]
for i in range(0,1000):
    documents.append(riskdf.iloc[i]['Riskfactors'])

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
len(documents)
# Out:
# 1000

# %%
true_k = 30
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=30, n_init=1, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :50]:
        print(' %s' % terms[ind]),
    print

print("\n")

print("Prediction")
# Out:
# Top terms per cluster:
# Cluster 0:
#  projects
#  business
#  operations
#  financial
#  contracts
#  project
#  costs
#  results
#  energy
#  customers
#  result
#  future
#  adversely
#  including
#  gas
#  significant
#  affect
#  backlog
#  contract
#  renewable
#  construction
#  work
#  services
#  impact
#  subject
#  cash
#  laws
#  ability
#  certain
#  subcontractors
#  material
#  adverse
#  regulations
#  condition
#  changes
#  utilities
#  electric
#  risks
#  additional
#  conditions
#  revenues
#  new
#  environmental
#  price
#  tax
#  addition
#  flows
#  facilities
#  electricity
#  power
# Cluster 1:
#  business
#  medicare
#  care
#  healthcare
#  medicaid
#  operations
#  financial
#  patients
#  services
#  hospitals
#  results
#  reimbursement
#  health
#  including
#  payors
#  facilities
#  patient
#  adversely
#  result
#  adverse
#  changes
#  significant
#  medical
#  ability
#  future
#  subject
#  physicians
#  cms
#  certain
#  programs
#  federal
#  state
#  information
#  affect
#  impact
#  costs
#  laws
#  material
#  providers
#  regulations
#  effect
#  operating
#  hospital
#  addition
#  aca
#  stock
#  condition
#  nursing
#  insurance
#  systems
# Cluster 2:
#  properties
#  reit
#  tenants
#  real
#  estate
#  tax
#  property
#  income
#  partnership
#  stock
#  distributions
#  financial
#  ability
#  business
#  debt
#  adversely
#  including
#  tenant
#  operations
#  leases
#  result
#  rental
#  affect
#  common
#  rent
#  certain
#  cash
#  reits
#  shares
#  taxable
#  lease
#  market
#  results
#  stockholders
#  space
#  future
#  subject
#  operating
#  costs
#  shareholders
#  capital
#  rates
#  qualify
#  make
#  condition
#  adverse
#  risks
#  value
#  terms
#  addition
# Cluster 3:
#  business
#  operations
#  financial
#  results
#  stock
#  including
#  adversely
#  ability
#  result
#  future
#  affect
#  company
#  common
#  significant
#  adverse
#  market
#  costs
#  subject
#  new
#  services
#  certain
#  material
#  impact
#  effect
#  condition
#  changes
#  tax
#  regulations
#  cash
#  additional
#  products
#  operating
#  laws
#  risks
#  customers
#  shares
#  price
#  time
#  addition
#  credit
#  capital
#  increase
#  information
#  factors
#  debt
#  conditions
#  stockholders
#  sales
#  management
#  assets
# Cluster 4:
#  loans
#  loan
#  financial
#  bank
#  business
#  operations
#  deposits
#  estate
#  real
#  results
#  banking
#  losses
#  capital
#  market
#  risk
#  mortgage
#  adversely
#  affect
#  ability
#  allowance
#  result
#  including
#  condition
#  borrowers
#  changes
#  credit
#  institutions
#  regulatory
#  services
#  lending
#  rates
#  company
#  deposit
#  portfolio
#  adverse
#  stock
#  banks
#  assets
#  future
#  securities
#  federal
#  customers
#  new
#  risks
#  subject
#  conditions
#  value
#  impact
#  increase
#  effect
# Cluster 5:
#  merchandise
#  stores
#  business
#  operations
#  results
#  financial
#  products
#  sales
#  adversely
#  including
#  affect
#  costs
#  store
#  ability
#  retail
#  result
#  customers
#  inventory
#  consumer
#  new
#  adverse
#  impact
#  changes
#  future
#  significant
#  operating
#  condition
#  material
#  information
#  systems
#  retailers
#  shopping
#  factors
#  laws
#  brand
#  subject
#  effect
#  credit
#  apparel
#  distribution
#  product
#  conditions
#  stock
#  customer
#  addition
#  certain
#  market
#  risks
#  vendors
#  card
# Cluster 6:
#  clinical
#  product
#  drug
#  trials
#  fda
#  products
#  candidates
#  patent
#  business
#  approval
#  regulatory
#  patients
#  including
#  patents
#  commercialization
#  future
#  development
#  trial
#  drugs
#  stock
#  market
#  reimbursement
#  healthcare
#  ability
#  pharmaceutical
#  additional
#  financial
#  marketing
#  commercialize
#  result
#  results
#  manufacturing
#  approved
#  sales
#  operations
#  generic
#  significant
#  subject
#  studies
#  obtain
#  rights
#  certain
#  blood
#  candidate
#  patient
#  addition
#  iluvien
#  states
#  party
#  laws
# Cluster 7:
#  company
#  business
#  financial
#  operations
#  results
#  products
#  adversely
#  including
#  affect
#  tax
#  changes
#  result
#  subject
#  customers
#  future
#  significant
#  adverse
#  impact
#  risks
#  ability
#  laws
#  material
#  regulations
#  costs
#  condition
#  effect
#  certain
#  market
#  new
#  sales
#  information
#  credit
#  economic
#  rates
#  operating
#  conditions
#  risk
#  services
#  assets
#  stock
#  foreign
#  systems
#  addition
#  management
#  factors
#  capital
#  product
#  increase
#  additional
#  affected
# Cluster 8:
#  0095
#  products
#  business
#  financial
#  operations
#  results
#  stock
#  future
#  result
#  customers
#  adversely
#  ability
#  market
#  including
#  services
#  significant
#  operating
#  affect
#  new
#  common
#  contents
#  subject
#  table
#  certain
#  costs
#  changes
#  product
#  laws
#  adverse
#  tax
#  condition
#  price
#  addition
#  material
#  sales
#  time
#  impact
#  risks
#  regulations
#  additional
#  effect
#  shares
#  cash
#  revenue
#  software
#  company
#  able
#  systems
#  fi
#  stockholders
# Cluster 9:
#  reinsurance
#  insurance
#  business
#  financial
#  operations
#  results
#  underwriting
#  adversely
#  risk
#  ability
#  subsidiaries
#  condition
#  company
#  affect
#  catastrophe
#  policyholders
#  including
#  market
#  claims
#  loss
#  changes
#  result
#  future
#  subject
#  capital
#  investment
#  losses
#  bermuda
#  ratings
#  risks
#  regulatory
#  adverse
#  premiums
#  companies
#  certain
#  rates
#  reinsurers
#  effect
#  reserves
#  securities
#  material
#  products
#  laws
#  impact
#  policies
#  significant
#  tax
#  income
#  information
#  casualty
# Cluster 10:
#  products
#  business
#  fda
#  product
#  financial
#  operations
#  medical
#  clinical
#  including
#  results
#  market
#  healthcare
#  future
#  result
#  device
#  regulatory
#  stock
#  sales
#  significant
#  subject
#  new
#  ability
#  patent
#  laws
#  reimbursement
#  adverse
#  manufacturing
#  patents
#  certain
#  clearance
#  adversely
#  addition
#  time
#  foreign
#  additional
#  regulations
#  information
#  common
#  affect
#  approval
#  effect
#  development
#  intellectual
#  care
#  devices
#  rights
#  costs
#  marketing
#  condition
#  changes
# Cluster 11:
#  trust
#  mv
#  realty
#  properties
#  unitholders
#  gas
#  digital
#  royalty
#  trustee
#  oil
#  underlying
#  owners
#  0095
#  production
#  net
#  partners
#  distributions
#  natural
#  proceeds
#  costs
#  operations
#  working
#  reit
#  reserves
#  wells
#  units
#  financial
#  result
#  partnership
#  future
#  centers
#  prices
#  cash
#  regulations
#  profits
#  including
#  affect
#  development
#  business
#  space
#  data
#  adversely
#  laws
#  emissions
#  greenhouse
#  customers
#  environmental
#  proved
#  tax
#  attributable
# Cluster 12:
#  item
#  factors
#  risk
#  1a
#  smaller
#  required
#  reporting
#  applicable
#  company
#  reference
#  incorporated
#  heading
#  md
#  companies
#  information
#  provide
#  disclosures
#  annual
#  report
#  pursuant
#  disclosure
#  forth
#  make
#  set
#  portion
#  epilepsies
#  epilepticus
#  epidemiologists
#  episodes
#  episode
#  epidemiology
#  epidermal
#  epiphany
#  epinephrine
#  epileptic
#  epigenomics
#  epidermolysis
#  epidural
#  epigenetic
#  environments
#  epigenetics
#  epigenetix
#  enviroplex
#  epilepsy
#  envirostar
#  epidemics
#  epidemiological
#  envisage
#  envisaged
#  envisioned
# Cluster 13:
#  gaming
#  casino
#  business
#  operations
#  racing
#  casinos
#  mgm
#  wagering
#  glpi
#  patrons
#  horse
#  games
#  macau
#  including
#  financial
#  new
#  subject
#  native
#  results
#  adverse
#  racetracks
#  rfid
#  mgp
#  laws
#  racetrack
#  slot
#  significant
#  ability
#  cma
#  future
#  card
#  adversely
#  products
#  kien
#  huat
#  cash
#  properties
#  result
#  costs
#  affect
#  smsc
#  regulations
#  indebtedness
#  addition
#  paradise
#  condition
#  changes
#  certain
#  effect
#  entertainment
# Cluster 14:
#  clients
#  business
#  financial
#  client
#  services
#  operations
#  results
#  including
#  adversely
#  result
#  tax
#  ability
#  new
#  significant
#  solutions
#  information
#  future
#  changes
#  subject
#  affect
#  adverse
#  laws
#  certain
#  market
#  data
#  risks
#  regulations
#  systems
#  effect
#  impact
#  condition
#  investment
#  addition
#  costs
#  products
#  management
#  revenue
#  material
#  assets
#  regulatory
#  risk
#  stock
#  company
#  employees
#  credit
#  revenues
#  operating
#  time
#  additional
#  service
# Cluster 15:
#  hotel
#  hotels
#  reit
#  lodging
#  trs
#  properties
#  rmr
#  company
#  shareholders
#  ashford
#  income
#  shares
#  distributions
#  business
#  host
#  tax
#  trustees
#  common
#  franchise
#  trss
#  managers
#  travel
#  ability
#  including
#  future
#  financial
#  adversely
#  taxable
#  reits
#  qualify
#  llc
#  stock
#  operations
#  subject
#  affect
#  capital
#  market
#  result
#  debt
#  marriott
#  results
#  management
#  operating
#  property
#  certain
#  make
#  leases
#  ta
#  room
#  cash
# Cluster 16:
#  25aa
#  products
#  business
#  customers
#  solutions
#  verticals
#  software
#  results
#  future
#  operations
#  new
#  ability
#  oil
#  market
#  semiconductor
#  services
#  gas
#  stock
#  financial
#  adversely
#  result
#  fracturing
#  revenue
#  operating
#  significant
#  demand
#  emissions
#  product
#  gan
#  ghg
#  addition
#  common
#  subject
#  laws
#  hydraulic
#  affect
#  customer
#  time
#  smbs
#  cloud
#  countries
#  class
#  manufacturing
#  regulations
#  certain
#  clients
#  sales
#  including
#  industry
#  technology
# Cluster 17:
#  business
#  products
#  customers
#  financial
#  results
#  stock
#  services
#  operations
#  future
#  result
#  new
#  including
#  market
#  ability
#  operating
#  software
#  common
#  significant
#  adversely
#  sales
#  solutions
#  revenue
#  affect
#  price
#  subject
#  data
#  intellectual
#  laws
#  certain
#  tax
#  changes
#  addition
#  time
#  customer
#  additional
#  rights
#  technology
#  condition
#  information
#  costs
#  regulations
#  use
#  adverse
#  property
#  management
#  platform
#  product
#  continue
#  risks
#  effect
# Cluster 18:
#  coal
#  mining
#  unitholders
#  operations
#  fired
#  cnx
#  units
#  reserves
#  consol
#  partner
#  plants
#  electric
#  mines
#  energy
#  business
#  emissions
#  future
#  including
#  gas
#  electricity
#  financial
#  ability
#  result
#  cash
#  epa
#  customers
#  reclamation
#  adversely
#  costs
#  partnership
#  power
#  results
#  production
#  affect
#  surety
#  price
#  tax
#  transportation
#  fuel
#  federal
#  regulations
#  general
#  demand
#  permits
#  prices
#  generators
#  contracts
#  fueled
#  bonds
#  income
# Cluster 19:
#  gas
#  oil
#  drilling
#  natural
#  operations
#  fracturing
#  hydraulic
#  production
#  crude
#  wells
#  reserves
#  business
#  financial
#  future
#  results
#  proved
#  prices
#  result
#  properties
#  ability
#  including
#  adversely
#  exploration
#  affect
#  water
#  costs
#  cash
#  capital
#  certain
#  regulations
#  equipment
#  operating
#  stock
#  subject
#  ngls
#  condition
#  epa
#  emissions
#  adverse
#  services
#  significant
#  risks
#  commodity
#  additional
#  activities
#  effect
#  environmental
#  price
#  new
#  addition
# Cluster 20:
#  unitholders
#  units
#  partner
#  partnership
#  unitholder
#  gas
#  oil
#  common
#  distributions
#  general
#  cash
#  income
#  tax
#  business
#  crude
#  operations
#  distribution
#  ability
#  natural
#  including
#  agreement
#  pipelines
#  result
#  financial
#  fracturing
#  pbf
#  frac
#  federal
#  irs
#  drilling
#  sand
#  subject
#  taxable
#  ferc
#  delek
#  future
#  certain
#  hydraulic
#  make
#  affect
#  costs
#  results
#  energy
#  assets
#  production
#  affiliates
#  adversely
#  oasis
#  available
#  interests
# Cluster 21:
#  reit
#  stock
#  income
#  tax
#  tenants
#  esh
#  reits
#  taxable
#  stockholders
#  northstar
#  business
#  real
#  distributions
#  ability
#  qualify
#  colony
#  estate
#  common
#  subject
#  partnership
#  investment
#  properties
#  shares
#  affect
#  adversely
#  financial
#  cim
#  preferred
#  certain
#  federal
#  assets
#  including
#  result
#  tenant
#  investments
#  manager
#  cash
#  debt
#  value
#  operations
#  dividends
#  securities
#  changes
#  qualification
#  rates
#  series
#  directors
#  stores
#  capital
#  property
# Cluster 22:
#  investment
#  portfolio
#  investments
#  securities
#  business
#  loans
#  value
#  income
#  mortgage
#  financial
#  stock
#  debt
#  assets
#  reit
#  market
#  1940
#  common
#  result
#  bdc
#  companies
#  ability
#  company
#  manager
#  ric
#  certain
#  including
#  tax
#  operations
#  loan
#  subject
#  adversely
#  capital
#  asset
#  affect
#  results
#  net
#  distributions
#  future
#  stockholders
#  notes
#  mbs
#  make
#  sba
#  time
#  cash
#  funds
#  credit
#  shares
#  act
#  sbic
# Cluster 23:
#  mattel
#  toys
#  products
#  business
#  operations
#  results
#  toy
#  new
#  financial
#  significant
#  sales
#  product
#  credit
#  revolving
#  games
#  children
#  costs
#  including
#  movies
#  customers
#  impact
#  secured
#  consumer
#  adversely
#  savings
#  popular
#  ability
#  retail
#  facilities
#  data
#  indebtedness
#  increase
#  addition
#  affect
#  cost
#  media
#  senior
#  result
#  capital
#  intellectual
#  season
#  entertainment
#  future
#  holiday
#  traditional
#  changes
#  adverse
#  condition
#  additional
#  vendors
# Cluster 24:
#  products
#  business
#  semiconductor
#  customers
#  results
#  financial
#  operations
#  manufacturing
#  future
#  product
#  new
#  significant
#  tax
#  adversely
#  result
#  ability
#  customer
#  including
#  operating
#  market
#  sales
#  china
#  stock
#  revenue
#  affect
#  changes
#  intellectual
#  certain
#  wafer
#  costs
#  impact
#  time
#  suppliers
#  demand
#  foreign
#  addition
#  subject
#  technology
#  condition
#  property
#  price
#  adverse
#  orders
#  markets
#  inventory
#  equipment
#  additional
#  industry
#  laws
#  systems
# Cluster 25:
#  feff
#  remoxy
#  drug
#  fda
#  clinical
#  candidates
#  durect
#  abuse
#  deterrent
#  trials
#  drugs
#  product
#  collaborators
#  opioid
#  products
#  noramco
#  approval
#  nda
#  studies
#  healthcare
#  opioids
#  commercialize
#  stock
#  oxycodone
#  preclinical
#  regulatory
#  business
#  deterrence
#  reimbursement
#  market
#  commercialization
#  manufacturing
#  pfizer
#  crl
#  labeling
#  commercial
#  future
#  additional
#  approved
#  result
#  mallinckrodt
#  common
#  candidate
#  potential
#  able
#  dea
#  payors
#  marketing
#  including
#  data
# Cluster 26:
#  products
#  business
#  financial
#  customers
#  results
#  contracts
#  government
#  operations
#  future
#  result
#  including
#  adversely
#  ability
#  significant
#  costs
#  new
#  services
#  sales
#  affect
#  contract
#  market
#  product
#  operating
#  subject
#  certain
#  stock
#  changes
#  addition
#  price
#  material
#  revenue
#  regulations
#  adverse
#  customer
#  systems
#  components
#  manufacturing
#  condition
#  tax
#  laws
#  effect
#  time
#  cost
#  defense
#  suppliers
#  intellectual
#  risks
#  impact
#  information
#  cash
# Cluster 27:
#  feff
#  company
#  business
#  financial
#  operations
#  results
#  belo
#  loans
#  result
#  ethanol
#  products
#  bcb
#  adverse
#  including
#  ability
#  stock
#  adversely
#  loan
#  condition
#  significant
#  affect
#  material
#  effect
#  market
#  costs
#  newsprint
#  changes
#  future
#  new
#  insurance
#  customers
#  voi
#  bank
#  subject
#  tax
#  risk
#  iab
#  impact
#  capital
#  reinsurance
#  services
#  icc
#  certain
#  tthe
#  common
#  credit
#  assets
#  oil
#  information
#  rates
# Cluster 28:
#  business
#  products
#  operations
#  financial
#  results
#  adversely
#  customers
#  affect
#  future
#  including
#  result
#  significant
#  costs
#  adverse
#  tax
#  ability
#  sales
#  material
#  impact
#  condition
#  changes
#  subject
#  certain
#  laws
#  product
#  market
#  effect
#  cash
#  new
#  risks
#  regulations
#  operating
#  stock
#  addition
#  raw
#  foreign
#  conditions
#  suppliers
#  manufacturing
#  credit
#  information
#  materials
#  factors
#  economic
#  price
#  additional
#  time
#  markets
#  assets
#  increase
# Cluster 29:
#  clinical
#  product
#  candidates
#  trials
#  fda
#  approval
#  products
#  patent
#  regulatory
#  drug
#  development
#  candidate
#  trial
#  commercialization
#  business
#  patents
#  collaborators
#  marketing
#  future
#  including
#  stock
#  commercialize
#  patients
#  market
#  studies
#  approved
#  manufacturing
#  ability
#  pharmaceutical
#  additional
#  result
#  obtain
#  preclinical
#  rights
#  intellectual
#  financial
#  research
#  healthcare
#  common
#  parties
#  reimbursement
#  party
#  significant
#  results
#  subject
#  drugs
#  operations
#  25cf
#  requirements
#  addition
#
#
# Prediction

# %%
Y = vectorizer.transform()
prediction = model.predict(Y)
print(prediction)
# Out:
# [7]

# %%
ct_df
# Out:
#     companyName                                     ticker  \
# 0           MMM                                 3M Company
# 1           ABT                        Abbott Laboratories
# 2           ABM                ABM Industries Incorporated
# 3           AKR                        Acadia Realty Trust
# 4           ACN                              Accenture plc
# 5           ATU                        Actuant Corporation
# 6           ALB                      Albemarle Corporation
# 7           LNT                 Alliant Energy Corporation
# 8           AEE                         Ameren Corporation
# 9           AMS          American Shared Hospital Services
# 10         ATLO                  Ames National Corporation
# 11          APH                       Amphenol Corporation
# 12          AXR                          AMREP Corporation
# 13         ANCB                             Anchor Bancorp
# 14          ANH         Anworth Mortgage Asset Corporation
# 15          ADM             Archer Daniels Midland Company
# 16         ACRE    Ares Commercial Real Estate Corporation
# 17         ATRO                      Astronics Corporation
# 18         ATLC            Atlanticus Holdings Corporation
# 19          ATO                   Atmos Energy Corporation
# 20          BOH                 Bank of Hawaii Corporation
# 21         BANR                         Banner Corporation
# 22         BBOX                      Black Box Corporation
# 23         BOKF                  BOK Financial Corporation
# 24          BAH    Booz Allen Hamilton Holding Corporation
# 25         BRKR                         Bruker Corporation
# 26          CPT                      Camden Property Trust
# 27          CPB                      Campbell Soup Company
# 28         CPHC        Canterbury Park Holding Corporation
# 29          COF          Capital One Financial Corporation
# ..          ...                                        ...
# 93         LGND        Ligand Pharmaceuticals Incorporated
# 94          LNC               Lincoln National Corporation
# 95         LMNX                        Luminex Corporation
# 96          LYB               LyondellBasell Industries NV
# 97         MRIN                Marin Software Incorporated
# 98          MAS                          Masco Corporation
# 99         MTRN                       Materion Corporation
# 100        MTRX                     Matrix Service Company
# 101         MGM                  MGM Resorts International
# 102         TAP               Molson Coors Brewing Company
# 103        NANO                   Nanometrics Incorporated
# 104         NAV         Navistar International Corporation
# 105        NPTN                   NeoPhotonics Corporation
# 106         NEU                      NewMarket Corporation
# 107        ORCL                         Oracle Corporation
# 108        PACW                            PacWest Bancorp
# 109         PAR                 PAR Technology Corporation
# 110         PVA                  Penn Virginia Corporation
# 111         PEI  Pennsylvania Real Estate Investment Trust
# 112         PNW          Pinnacle West Capital Corporation
# 113        PLPC            Preformed Line Products Company
# 114        PRMW                    Primo Water Corporation
# 115        PRIM              Primoris Services Corporation
# 116         PRA                   ProAssurance Corporation
# 117        PRGS              Progress Software Corporation
# 118          RL                   Ralph Lauren Corporation
# 119           O                  Realty Income Corporation
# 120         RLH                Red Lion Hotels Corporation
# 121        RGEN                       Repligen Corporation
# 122         REN                Resolute Energy Corporation
#
#                                                   risk
# 0    [1] "Item 1A. Risk Factors.. Provided below is...
# 1    [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 2    [1] "ITEM 1A. RISK FACTORS.. We may not realiz...
# 3    [1] "ITEM 1A. RISK FACTORS.. Set forth below a...
# 4    [1] "ITEM 1A.    RISK FACTORS. In addition to ...
# 5    [1] "Item  1A.    Risk Factors. The risks and ...
# 6    [1] "Item 1A. Risk Factors.. You should consid...
# 7    [1] "ITEM 1A. RISK FACTORS. You should careful...
# 8    [1] "ITEM 1A.  RISK FACTORS. Investors should ...
# 9    [1] "ITEM 1A. RISK FACTORS. In addition to the...
# 10   [1] "ITEM 1A.  RISK FACTORS. Set forth below i...
# 11   [1] "Item 1A. Risk Factors. Investors should c...
# 12           [1] "Item 1A.Risk Factors. Not required."
# 13   [1] "Item 1A.  Risk Factors.. An investment in...
# 14   [1] "Item 1A.     RISK FACTORS. Our business r...
# 15   [1] "Item 1A. RISK FACTORS. The Company faces ...
# 16   [1] "Item 1A.    Risk Factors. RISK FACTORS. Y...
# 17   [1] "ITEM 1A.    RISK FACTORS. The loss of Pan...
# 18   [1] "ITEM 1A. RISK FACTORS. An investment in o...
# 19   [1] "ITEM 1A. Risk Factors.. Our financial and...
# 20   [1] "Item 1A.  Risk Factors. There are a numbe...
# 21   [1] "Item 1A  -  Risk Factors. An investment i...
# 22   [1] "Item 1A. Risk Factors.. The following are...
# 23   [1] "ITEM 1A.   RISK FACTORS. BOK Financial Co...
# 24   [1] "Item 1A. Risk Factors. You should conside...
# 25   [1] "ITEM 1A    RISK FACTORS. The following ri...
# 26   [1] "Item 1A. Risk Factors. In addition to the...
# 27   [1] "Item 1A. Risk Factors. In addition to the...
# 28   [1] "Item 1A. RISK FACTORS. In addition to ris...
# 29   [1] "Item 1A. Risk Factors. This section highl...
# ..                                                 ...
# 93   [1] "ITEM 1A. RISK FACTORS. The following is a...
# 94   [1] "Item 1A.    Risk Factors. <U+FEFF>. You s...
# 95   [1] "ITEM 1A. RISK FACTORS. The life sciences ...
# 96   [1] "Item 1A. Risk Factors.. You should carefu...
# 97   [1] "ITEM 1A.  RISK FACTORS. Our operations an...
# 98   [1] "Item 1A.    Risk Factors.. There are a nu...
# 99   [1] "Item 1A.    RISK FACTORS. Our business, f...
# 100  [1] "Item 1A. Risk Factors. The following risk...
# 101  [1] "ITEM 1A.  RISK FACTORS. You should be awa...
# 102  [1] "ITEM 1A.    RISK FACTORS. Investing in ou...
# 103  [1] "ITEM 1A.  RISK FACTORS. In addition to th...
# 104  [1] "Item 1A. Risk Factors. Our financial cond...
# 105  [1] "ITEM 1A.    RISK FACTORS. Risks Associate...
# 106  [1] "ITEM 1A. RISK FACTORS. Our business is su...
# 107  [1] "Item 1A.    Risk Factors. We operate in r...
# 108  [1] "ITEM 1A.  RISK FACTORS. In the course of ...
# 109  [1] "Item 1A  Risk Factors.. Our business is s...
# 110  [1] "Item 1A    Risk Factors. Our business and...
# 111  [1] "ITEM 1A.    RISK FACTORS.. RISKS RELATED ...
# 112  [1] "ITEM 1A.  RISK FACTORS. In addition to th...
# 113  [1] "Item 1A. Risk Factors. Due to the Company...
# 114  [1] "Item 1A. Risk Factors. Risks Relating to ...
# 115  [1] "ITEM 1A.  RISK FACTORS. Our business is s...
# 116  [1] "ITEM 1A. RISK FACTORS.. There are a numbe...
# 117  [1] "Item 1A. Risk Factors. We operate in a ra...
# 118  [1] "Item 1A. Risk Factors. There are risks as...
# 119  [1] "Item 1A:      Risk Factors. This \"Risk F...
# 120  [1] "Item 1A. Risk Factors. We are subject to ...
# 121  [1] "ITEM 1A. RISK FACTORS. Investors should c...
# 122  [1] "ITEM 1A.  RISK FACTORS. You should consid...
#
# [123 rows x 3 columns]

# %%
clusterT=[]
cluster=[]

clusterN=[]

for i in range(0,121):
    Y = vectorizer.transform([ct_df.iloc[i]['risk']])
    prediction = model.predict(Y)
    cluster.append(prediction)
    clusterN.append([ct_df.iloc[i]['companyName']]) 
    clusterT.append([ct_df.iloc[i]['ticker']]) 
                                                                                 
# predictions_dict = {key:value for key, value in zip(, column_values)}
# print(predictions)
# Prediction_dict = dict(zip(clusterT, zip(cluster, clusterN))) 
# df['grades'] = grades
# ct_df['cluster']=cluster
dfgg = pd.DataFrame(clusterN)
dfgg['companyname']=clusterT
dfgg['cluster']=cluster

# %%
# prediction1=[]
# predictionN=[]

# predictions=dict()
# count=0

# for i in range(0,100):
#     Y = vectorizer.transform([riskdf.iloc[i]['Riskfactors']])
#     prediction = model.predict(Y)
#     prediction1.append(prediction)
#     count=+1
#     predictionN.append([riskdf.iloc[i]['filename']])
#     predictions.update({prediction1:predictionN})
# for i in range(0,3):
#     Y = vectorizer.transform([ct_df.iloc[i]['risk']])
#     prediction = model.predict(Y)

# %%
dfgg
# Out:
#         0                                  companyname cluster
# 0     MMM                                 [3M Company]     [7]
# 1     ABT                        [Abbott Laboratories]     [3]
# 2     ABM                [ABM Industries Incorporated]    [14]
# 3     AKR                        [Acadia Realty Trust]     [2]
# 4     ACN                              [Accenture plc]    [14]
# 5     ATU                        [Actuant Corporation]    [28]
# 6     ALB                      [Albemarle Corporation]    [28]
# 7     LNT                 [Alliant Energy Corporation]     [0]
# 8     AEE                         [Ameren Corporation]     [3]
# 9     AMS          [American Shared Hospital Services]     [3]
# 10   ATLO                  [Ames National Corporation]     [4]
# 11    APH                       [Amphenol Corporation]     [7]
# 12    AXR                          [AMREP Corporation]    [12]
# 13   ANCB                             [Anchor Bancorp]     [4]
# 14    ANH         [Anworth Mortgage Asset Corporation]    [22]
# 15    ADM             [Archer Daniels Midland Company]     [7]
# 16   ACRE    [Ares Commercial Real Estate Corporation]    [22]
# 17   ATRO                      [Astronics Corporation]    [26]
# 18   ATLC            [Atlanticus Holdings Corporation]     [3]
# 19    ATO                   [Atmos Energy Corporation]    [28]
# 20    BOH                 [Bank of Hawaii Corporation]     [4]
# 21   BANR                         [Banner Corporation]     [4]
# 22   BBOX                      [Black Box Corporation]    [14]
# 23   BOKF                  [BOK Financial Corporation]     [3]
# 24    BAH    [Booz Allen Hamilton Holding Corporation]    [26]
# 25   BRKR                         [Bruker Corporation]     [8]
# 26    CPT                      [Camden Property Trust]     [2]
# 27    CPB                      [Campbell Soup Company]    [28]
# 28   CPHC        [Canterbury Park Holding Corporation]    [13]
# 29    COF          [Capital One Financial Corporation]     [4]
# ..    ...                                          ...     ...
# 91   LANC               [Lancaster Colony Corporation]    [28]
# 92    LRY                     [Liberty Property Trust]     [2]
# 93   LGND        [Ligand Pharmaceuticals Incorporated]     [6]
# 94    LNC               [Lincoln National Corporation]    [27]
# 95   LMNX                        [Luminex Corporation]    [10]
# 96    LYB               [LyondellBasell Industries NV]     [8]
# 97   MRIN                [Marin Software Incorporated]    [17]
# 98    MAS                          [Masco Corporation]    [28]
# 99   MTRN                       [Materion Corporation]     [3]
# 100  MTRX                     [Matrix Service Company]     [0]
# 101   MGM                  [MGM Resorts International]    [13]
# 102   TAP               [Molson Coors Brewing Company]    [28]
# 103  NANO                   [Nanometrics Incorporated]    [24]
# 104   NAV         [Navistar International Corporation]    [28]
# 105  NPTN                   [NeoPhotonics Corporation]    [24]
# 106   NEU                      [NewMarket Corporation]    [28]
# 107  ORCL                         [Oracle Corporation]     [8]
# 108  PACW                            [PacWest Bancorp]     [4]
# 109   PAR                 [PAR Technology Corporation]    [26]
# 110   PVA                  [Penn Virginia Corporation]    [19]
# 111   PEI  [Pennsylvania Real Estate Investment Trust]     [2]
# 112   PNW          [Pinnacle West Capital Corporation]     [3]
# 113  PLPC            [Preformed Line Products Company]     [7]
# 114  PRMW                    [Primo Water Corporation]    [28]
# 115  PRIM              [Primoris Services Corporation]     [0]
# 116   PRA                   [ProAssurance Corporation]     [9]
# 117  PRGS              [Progress Software Corporation]    [17]
# 118    RL                   [Ralph Lauren Corporation]     [5]
# 119     O                  [Realty Income Corporation]     [2]
# 120   RLH                [Red Lion Hotels Corporation]    [15]
#
# [121 rows x 3 columns]

# %%
dfgg.to_csv("outputclustering120.csv", index=True)

# %%
papercluster = pd.read_csv('paperclusterlabels3.csv')
papercluster.head()
# Out:
#                                                topic  \
# 0  Topic 0: investment, property, distribution, i...
# 1  Topic 1: regulation, change, law, financial, o...
# 2  Topic 2: gas, price, oil, natural, operation, ...
# 3  Topic 3: stock, price, share, market, future, ...
# 4  Topic 4: cost, regulation, environmental, law,...
#
#                                 risk
# 0        Shareholders interest risk
# 1   *Regulation changes(accounting)
# 2                Input prices risks
# 3            ** Stakeholders profit
# 4  *Regulation changes(environment)

# %%
clusterTopic=[]
clusternumber=[]

clusterlabel=[]

for i in range(0,30):
    Y = vectorizer.transform([papercluster.iloc[i]['topic']])
    prediction = model.predict(Y)
    clusternumber.append(prediction)
    clusterlabel.append([papercluster.iloc[i]['risk']]) 
    clusterTopic.append( ) 
                                                                                 
# predictions_dict = {key:value for key, value in zip(, column_values)}
# print(predictions)
# Prediction_dict = dict(zip(clusterT, zip(cluster, clusterN))) 
# df['grades'] = grades
# ct_df['cluster']=cluster
topiccluster = pd.DataFrame(clusterTopic)
topiccluster ['risklabel']=clusterlabel
topiccluster ['cluster']=clusternumber
topiccluster.head()
# Out:
#                                                    0  \
# 0  Topic 0: investment, property, distribution, i...
# 1  Topic 1: regulation, change, law, financial, o...
# 2  Topic 2: gas, price, oil, natural, operation, ...
# 3  Topic 3: stock, price, share, market, future, ...
# 4  Topic 4: cost, regulation, environmental, law,...
#
#                              risklabel cluster
# 0        [Shareholders interest risk ]     [3]
# 1   [*Regulation changes(accounting) ]     [3]
# 2                [Input prices risks ]    [19]
# 3            [** Stakeholders profit ]     [3]
# 4  [*Regulation changes(environment) ]     [3]

# %%
topiccluster
# Out:
#                                             risklabel cluster
# 0                       [Shareholders interest risk ]     [3]
# 1                  [*Regulation changes(accounting) ]     [3]
# 2                               [Input prices risks ]    [19]
# 3                           [** Stakeholders profit ]     [3]
# 4                 [*Regulation changes(environment) ]     [3]
# 5                        [Financial condition risks ]     [3]
# 6                      [*Potential/Ongoing Lawsuits ]     [3]
# 7                                [Competition risks ]     [3]
# 8                                     [**Labor cost ]     [3]
# 9                   [New product introduction risks ]     [6]
# 10              [**Accounting, +Restructuring risks ]     [3]
# 11                                    [**Management ]     [3]
# 12                   [Potential defects in products ]     [3]
# 13                                    [**Investment ]     [3]
# 14                            [Human resource risks ]     [3]
# 15                      [Volatile stock price risks ]     [3]
# 16                      [Merger & Acquisition risks ]     [3]
# 17      [Macroeconomic risks, +Industry is cyclical ]     [3]
# 18  [Disruption of operations, +Infrastructure ris...     [3]
# 19                                      [**Postpone ]     [3]
# 20  [Rely on few large customers, +Suppliers risks...     [3]
# 21  [Intellectual property risks, +Licensing relat...     [3]
# 22  [Volatile demand and results, + Competition ri...     [3]
# 23                     [*Potential/Ongoing Lawsuits ]     [3]
# 24                             [*Regulation changes ]     [3]
# 25                                  [**Credit risks ]     [3]
# 26                                   [Funding risks ]     [3]
# 27                             [International risks ]     [3]
# 28                                     [**Insurance ]     [3]
# 29                                    [Catastrophes ]     [3]

# %%
true_k = 999
model2 = KMeans(n_clusters=true_k, random_state=90, init='k-means++', max_iter=150, n_init=10)
model2.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-347-09ae3a457b99> in <module>()
#       1 true_k = 1200
#       2 model2 = KMeans(n_clusters=true_k, random_state=90, init='k-means++', max_iter=150, n_init=10)
# ----> 3 model2.fit(X)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     313     if _num_samples(X) < n_clusters:
#     314         raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
# --> 315             _num_samples(X), n_clusters))
#     316
#     317     tol = _tolerance(X, tol)
#
# ValueError: n_samples=1000 should be >= n_clusters=1200

# %%
clusterTopic2=[]
clusternumber2=[]

clusterlabel2=[]

for i in range(0,30):
    Y = vectorizer.transform([papercluster.iloc[i]['topic']])
    prediction = model2.predict(Y)
    clusternumber2.append(prediction)
    clusterlabel2.append([papercluster.iloc[i]['risk']]) 
    clusterTopic2.append([papercluster.iloc[i]['topic']]) 
                                                                                 
# predictions_dict = {key:value for key, value in zip(, column_values)}
# print(predictions)
# Prediction_dict = dict(zip(clusterT, zip(cluster, clusterN))) 

# df['grades'] = grades
# ct_df['cluster']=cluster
topiccluster2 = pd.DataFrame(clusterTopic2)
topiccluster2 ['risklabel']=clusterlabel2
topiccluster2 ['cluster']=clusternumber2
topiccluster2
# Out:
#                                                     0  \
# 0   Topic 0: investment, property, distribution, i...
# 1   Topic 1: regulation, change, law, financial, o...
# 2   Topic 2: gas, price, oil, natural, operation, ...
# 3   Topic 3: stock, price, share, market, future, ...
# 4   Topic 4: cost, regulation, environmental, law,...
# 5   Topic 5: control, financial, internal, loss, r...
# 6   Topic 6: financial, litigation, operation, con...
# 7   Topic 7: competitive, industry, competition, h...
# 8   Topic 8: cost, operation, labor, operating, em...
# 9   Topic 9: product, candidate, development, appr...
# 10  Topic 10: tax, income, asset, net, goodwill, l...
# 11  Topic 11: interest, director, officer, trust, ...
# 12  ?Topic 12: product, liability, claim, market, ...
# 13  Topic 13: loan, real, estate, investment, prop...
# 14  Topic 14: personnel, key, retain, attract, man...
# 15  Topic 15: stock, price, operating, stockholder...
# 16  Topic 16: acquisition, growth, future, operati...
# 17  Topic 17: condition, economic, financial, mark...
# 18  Topic 18: system, service, information, failur...
# 19  Topic 19: cost, contract, operation, plan, inc...
# 20  Topic 20: customer, product, revenue, sale, su...
# 21  Topic 21: property, intellectual, protect, pro...
# 22  Topic 22: product, market, service, change, sa...
# 23  Topic 23: provision, law, control, change, sto...
# 24  Topic 24: regulation, government, change, reve...
# 25  Topic 25: capital, credit, financial, market, ...
# 26  Topic 26: debt, indebtedness, cash, obligation...
# 27  Topic 27: operation, international, foreign, c...
# 28  Topic 28: loss, insurance, financial, loan, re...
# 29  Topic 29: operation, natural, facility, disast...
#
#                                             risklabel cluster
# 0                       [Shareholders interest risk ]     [4]
# 1                  [*Regulation changes(accounting) ]   [204]
# 2                               [Input prices risks ]     [9]
# 3                           [** Stakeholders profit ]   [204]
# 4                 [*Regulation changes(environment) ]     [3]
# 5                        [Financial condition risks ]   [204]
# 6                      [*Potential/Ongoing Lawsuits ]   [204]
# 7                                [Competition risks ]   [204]
# 8                                     [**Labor cost ]     [3]
# 9                   [New product introduction risks ]     [1]
# 10              [**Accounting, +Restructuring risks ]     [3]
# 11                                    [**Management ]    [84]
# 12                   [Potential defects in products ]     [1]
# 13                                    [**Investment ]   [412]
# 14                            [Human resource risks ]     [3]
# 15                      [Volatile stock price risks ]   [675]
# 16                      [Merger & Acquisition risks ]   [204]
# 17      [Macroeconomic risks, +Industry is cyclical ]   [204]
# 18  [Disruption of operations, +Infrastructure ris...   [710]
# 19                                      [**Postpone ]   [407]
# 20  [Rely on few large customers, +Suppliers risks...     [1]
# 21  [Intellectual property risks, +Licensing relat...   [309]
# 22  [Volatile demand and results, + Competition ri...     [1]
# 23                     [*Potential/Ongoing Lawsuits ]     [4]
# 24                             [*Regulation changes ]   [874]
# 25                                  [**Credit risks ]   [204]
# 26                                   [Funding risks ]   [204]
# 27                             [International risks ]     [3]
# 28                                     [**Insurance ]   [204]
# 29                                    [Catastrophes ]   [696]

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
papercluster = pd.read_csv('paperclusterlabels3.csv')
papercluster.head()
# Out:
#                                                topic  \
# 0  Topic 0: investment, property, distribution, i...
# 1  Topic 1: regulation, change, law, financial, o...
# 2  Topic 2: gas, price, oil, natural, operation, ...
# 3  Topic 3: stock, price, share, market, future, ...
# 4  Topic 4: cost, regulation, environmental, law,...
#
#                                 risk
# 0        Shareholders interest risk
# 1   *Regulation changes(accounting)
# 2                Input prices risks
# 3            ** Stakeholders profit
# 4  *Regulation changes(environment)

# %%
Y = vectorizer.transform([papercluster.iloc[9]['topic']])
prediction = model.predict(Y)
print(prediction)
# Out:
# [6]

# %%
[papercluster.iloc[25]['topic']]
# Out:
# ['Topic 25: capital, credit, financial, market, cost, operation, rating, access, liquidity, downgrade ']

# %%
import pandas as pd
import quandl
quandl.ApiConfig.api_key = 'p69T9SAkSfzeuKRTX2x7'
import datetime
 
# We will look at stock prices over the past year, starting at January 1, 2016
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2018,1,2)
 
# Let's get Apple stock data; Apple's ticker symbol is AAPL
# First argument is the series we want, second is the source ("yahoo" for Yahoo! Finance), third is the start date, fourth is the end date
s = "GOOG"
apple = quandl.get("WIKI/" + s, start_date=start, end_date=end)
 
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
apple.head()
# Out:
#                Open     High      Low   Close     Volume  Ex-Dividend  \
# Date
# 2018-01-02  1048.34  1066.94  1045.23  1065.0  1223114.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-01-02          1.0    1048.34    1066.94   1045.23      1065.0
#
#             Adj. Volume
# Date
# 2018-01-02    1223114.0

# %%
s = "GOOGL"
google = quandl.get("WIKI/" + s, start_date=start, end_date=end)

# %%
tikrs=[]
for i in range(0,120):
    tikr=[dfgg.iloc[i][0]]
    tikrs.append(tikr)

# %%
dataq = quandl.get_table('WIKI/PRICES', ticker = tikrs, 
                        qopts = { 'columns': ['ticker', 'date', 'adj_close','adj_volume']}, 
                        date = { 'gte': '2017-01-02', 'lte': '2017-01-03' }, 
                        paginate=True)
dataq
# Out:
#      ticker       date   adj_close    adj_volume
# None
# 0       TAP 2017-01-03   96.625645  1.105063e+06
# 1        RL 2017-01-03   88.972387  1.434366e+06
# 2      PRIM 2017-01-03   23.021564  2.075390e+05
# 3      PRGS 2017-01-03   31.658182  1.556510e+05
# 4       PRA 2017-01-03   55.111216  2.980780e+05
# 5       PNW 2017-01-03   74.916485  5.173040e+05
# 6      PLPC 2017-01-03   57.220523  5.203000e+03
# 7       PEI 2017-01-03   18.333045  7.075230e+05
# 8      PACW 2017-01-03   52.865970  7.239020e+05
# 9      ORCL 2017-01-03   38.090088  1.105134e+07
# 10        O 2017-01-03   55.419014  1.973258e+06
# 11     NPTN 2017-01-03   10.890000  7.268680e+05
# 12      NEU 2017-01-03  423.747414  3.305600e+04
# 13      NAV 2017-01-03   31.840000  6.300990e+05
# 14     NANO 2017-01-03   24.950000  1.656260e+05
# 15     MTRX 2017-01-03   23.000000  1.256370e+05
# 16     MTRN 2017-01-03   39.658540  9.132800e+04
# 17     MRIN 2017-01-03   16.800000  6.619286e+03
# 18      MMM 2017-01-03  174.831943  2.510055e+06
# 19      MGM 2017-01-03   29.159559  9.439195e+06
# 20      MAS 2017-01-03   31.866486  2.660933e+06
# 21      LYB 2017-01-03   84.295272  2.560315e+06
# 22     LRCX 2017-01-03  105.982490  1.937513e+06
# 23      LNT 2017-01-03   36.756680  8.666260e+05
# 24      LNC 2017-01-03   65.799744  1.578206e+06
# 25     LMNX 2017-01-03   20.212443  1.404470e+05
# 26     LION 2017-01-03   23.213722  1.305490e+05
# 27     LGND 2017-01-03  102.500000  2.553100e+05
# 28     LANC 2017-01-03  139.824918  9.086900e+04
# 29     IRET 2017-01-03    6.923718  7.022870e+05
# ...     ...        ...         ...           ...
# 71     CMCO 2017-01-03   27.322472  1.085110e+05
# 72      CLW 2017-01-03   66.550000  4.545100e+04
# 73     CHSP 2017-01-03   24.973745  3.706410e+05
# 74      CFX 2017-01-03   36.900000  1.000242e+06
# 75     CERS 2017-01-03    4.330000  6.359490e+05
# 76     CELG 2017-01-03  118.750000  4.051809e+06
# 77      CCL 2017-01-03   51.178923  3.450973e+06
# 78      CCF 2017-01-03   85.650000  2.252200e+04
# 79      CBS 2017-01-03   63.841668  3.553848e+06
# 80     BUSE 2017-01-03   30.070442  1.024630e+05
# 81     BRKR 2017-01-03   21.482699  5.934780e+05
# 82     BOKF 2017-01-03   80.534127  2.197020e+05
# 83      BOH 2017-01-03   87.034406  2.665550e+05
# 84     BBOX 2017-01-03   14.875725  1.141010e+05
# 85     BANR 2017-01-03   54.366197  2.971410e+05
# 86      BAH 2017-01-03   35.203982  1.788875e+06
# 87      ATU 2017-01-03   26.708350  1.038151e+06
# 88     ATRO 2017-01-03   34.000000  9.465300e+04
# 89      ATO 2017-01-03   73.331112  4.515270e+05
# 90     ATLO 2017-01-03   32.131939  3.407000e+03
# 91      APH 2017-01-03   66.983896  8.266110e+05
# 92      ANH 2017-01-03    4.866323  8.379980e+05
# 93      ALB 2017-01-03   87.310827  9.755940e+05
# 94      AKR 2017-01-03   31.753996  6.367000e+05
# 95      AEE 2017-01-03   51.172942  1.107195e+06
# 96      ADM 2017-01-03   44.798018  3.614876e+06
# 97     ACRE 2017-01-03   13.255966  1.472830e+05
# 98      ACN 2017-01-03  114.153742  2.352157e+06
# 99      ABT 2017-01-03   38.170443  9.677316e+06
# 100     ABM 2017-01-03   40.312951  5.486920e+05
#
# [101 rows x 4 columns]

# %%
data = quandl.get_table('WIKI/PRICES', ticker = tikrs, 
                        qopts = { 'columns': ['ticker', 'date', 'adj_close','adj_volume'] }, 
                        date = { 'gte': '2018-01-01', 'lte': '2018-01-02' }, 
                        paginate=True)
data
# Out:
#      ticker       date  adj_close  adj_volume
# None
# 0       TAP 2018-01-02      82.24   1129690.0
# 1        RL 2018-01-02     104.88   1119979.0
# 2      PRIM 2018-01-02      27.48    135477.0
# 3      PRGS 2018-01-02      43.24    451038.0
# 4       PRA 2018-01-02      55.85    216274.0
# 5       PNW 2018-01-02      83.89    697495.0
# 6      PLPC 2018-01-02      72.40     10158.0
# 7       PEI 2018-01-02      12.47   1836336.0
# 8      PACW 2018-01-02      50.44   1178150.0
# 9      ORCL 2018-01-02      46.63  25309088.0
# 10        O 2018-01-02      56.62   1616390.0
# 11     NPTN 2018-01-02       7.18    977908.0
# 12      NEU 2018-01-02     403.63     63687.0
# 13      NAV 2018-01-02      43.63    382189.0
# 14     NANO 2018-01-02      25.25    193078.0
# 15     MTRX 2018-01-02      18.30    208983.0
# 16     MTRN 2018-01-02      50.00    366626.0
# 17     MRIN 2018-01-02      10.90      4139.0
# 18      MGM 2018-01-02      33.51   5446404.0
# 19      MAS 2018-01-02      43.81   1579123.0
# 20      LYB 2018-01-02     112.23   1113175.0
# 21     LRCX 2018-01-02     189.28   2009499.0
# 22      LNT 2018-01-02      42.11   1392947.0
# 23      LNC 2018-01-02      77.91   1294623.0
# 24     LMNX 2018-01-02      20.33    234566.0
# 25     LION 2018-01-02      21.85     75802.0
# 26     LGND 2018-01-02     138.63    127824.0
# 27     LANC 2018-01-02     128.71    117327.0
# 28     IRET 2018-01-02       5.69    632353.0
# 29     IRBT 2018-01-02      80.10    792566.0
# ...     ...        ...        ...         ...
# 70     CMCO 2018-01-02      41.15    122219.0
# 71      CLW 2018-01-02      46.20     56175.0
# 72     CHSP 2018-01-02      27.53    476219.0
# 73      CFX 2018-01-02      39.82    556633.0
# 74     CERS 2018-01-02       3.56    489322.0
# 75     CELG 2018-01-02     106.16   4724190.0
# 76      CCL 2018-01-02      66.75   2783766.0
# 77      CCF 2018-01-02     120.05     22930.0
# 78      CBS 2018-01-02      59.17   3177625.0
# 79     BUSE 2018-01-02      29.88    142211.0
# 80     BRKR 2018-01-02      34.52    313000.0
# 81     BOKF 2018-01-02      92.35    133073.0
# 82      BOH 2018-01-02      85.82    231924.0
# 83     BBOX 2018-01-02       3.50    293039.0
# 84     BANR 2018-01-02      55.17    150027.0
# 85      BAH 2018-01-02      37.96    488675.0
# 86      ATU 2018-01-02      25.05    912860.0
# 87     ATRO 2018-01-02      42.27    127527.0
# 88      ATO 2018-01-02      85.04    668765.0
# 89     ATLO 2018-01-02      28.10      7850.0
# 90      APH 2018-01-02      87.80   1227122.0
# 91      ANH 2018-01-02       5.37    839578.0
# 92      ALB 2018-01-02     131.53   1117717.0
# 93      AKR 2018-01-02      27.75    553012.0
# 94      AEE 2018-01-02      58.39   1189242.0
# 95      ADM 2018-01-02      40.09   3649242.0
# 96     ACRE 2018-01-02      12.79    164627.0
# 97      ACN 2018-01-02     153.84   2854628.0
# 98      ABT 2018-01-02      58.79  10112783.0
# 99      ABM 2018-01-02      37.75    653235.0
#
# [100 rows x 4 columns]

# %%
stockdf=pd.merge(data, dataq, on='ticker')

# %%
# data.head()
dataq.head()
# Out:
#      ticker       date  adj_close  adj_volume
# None
# 0       TAP 2017-01-03  96.625645   1105063.0
# 1        RL 2017-01-03  88.972387   1434366.0
# 2      PRIM 2017-01-03  23.021564    207539.0
# 3      PRGS 2017-01-03  31.658182    155651.0
# 4       PRA 2017-01-03  55.111216    298078.0

# %%
stockdf
# Out:
#    ticker     date_x  adj_close_x  adj_volume_x     date_y  adj_close_y  \
# 0     TAP 2018-01-02        82.24     1129690.0 2017-01-03    96.625645
# 1      RL 2018-01-02       104.88     1119979.0 2017-01-03    88.972387
# 2    PRIM 2018-01-02        27.48      135477.0 2017-01-03    23.021564
# 3    PRGS 2018-01-02        43.24      451038.0 2017-01-03    31.658182
# 4     PRA 2018-01-02        55.85      216274.0 2017-01-03    55.111216
# 5     PNW 2018-01-02        83.89      697495.0 2017-01-03    74.916485
# 6    PLPC 2018-01-02        72.40       10158.0 2017-01-03    57.220523
# 7     PEI 2018-01-02        12.47     1836336.0 2017-01-03    18.333045
# 8    PACW 2018-01-02        50.44     1178150.0 2017-01-03    52.865970
# 9    ORCL 2018-01-02        46.63    25309088.0 2017-01-03    38.090088
# 10      O 2018-01-02        56.62     1616390.0 2017-01-03    55.419014
# 11   NPTN 2018-01-02         7.18      977908.0 2017-01-03    10.890000
# 12    NEU 2018-01-02       403.63       63687.0 2017-01-03   423.747414
# 13    NAV 2018-01-02        43.63      382189.0 2017-01-03    31.840000
# 14   NANO 2018-01-02        25.25      193078.0 2017-01-03    24.950000
# 15   MTRX 2018-01-02        18.30      208983.0 2017-01-03    23.000000
# 16   MTRN 2018-01-02        50.00      366626.0 2017-01-03    39.658540
# 17   MRIN 2018-01-02        10.90        4139.0 2017-01-03    16.800000
# 18    MGM 2018-01-02        33.51     5446404.0 2017-01-03    29.159559
# 19    MAS 2018-01-02        43.81     1579123.0 2017-01-03    31.866486
# 20    LYB 2018-01-02       112.23     1113175.0 2017-01-03    84.295272
# 21   LRCX 2018-01-02       189.28     2009499.0 2017-01-03   105.982490
# 22    LNT 2018-01-02        42.11     1392947.0 2017-01-03    36.756680
# 23    LNC 2018-01-02        77.91     1294623.0 2017-01-03    65.799744
# 24   LMNX 2018-01-02        20.33      234566.0 2017-01-03    20.212443
# 25   LION 2018-01-02        21.85       75802.0 2017-01-03    23.213722
# 26   LGND 2018-01-02       138.63      127824.0 2017-01-03   102.500000
# 27   LANC 2018-01-02       128.71      117327.0 2017-01-03   139.824918
# 28   IRET 2018-01-02         5.69      632353.0 2017-01-03     6.923718
# 29   IRBT 2018-01-02        80.10      792566.0 2017-01-03    57.580000
# ..    ...        ...          ...           ...        ...          ...
# 70   CMCO 2018-01-02        41.15      122219.0 2017-01-03    27.322472
# 71    CLW 2018-01-02        46.20       56175.0 2017-01-03    66.550000
# 72   CHSP 2018-01-02        27.53      476219.0 2017-01-03    24.973745
# 73    CFX 2018-01-02        39.82      556633.0 2017-01-03    36.900000
# 74   CERS 2018-01-02         3.56      489322.0 2017-01-03     4.330000
# 75   CELG 2018-01-02       106.16     4724190.0 2017-01-03   118.750000
# 76    CCL 2018-01-02        66.75     2783766.0 2017-01-03    51.178923
# 77    CCF 2018-01-02       120.05       22930.0 2017-01-03    85.650000
# 78    CBS 2018-01-02        59.17     3177625.0 2017-01-03    63.841668
# 79   BUSE 2018-01-02        29.88      142211.0 2017-01-03    30.070442
# 80   BRKR 2018-01-02        34.52      313000.0 2017-01-03    21.482699
# 81   BOKF 2018-01-02        92.35      133073.0 2017-01-03    80.534127
# 82    BOH 2018-01-02        85.82      231924.0 2017-01-03    87.034406
# 83   BBOX 2018-01-02         3.50      293039.0 2017-01-03    14.875725
# 84   BANR 2018-01-02        55.17      150027.0 2017-01-03    54.366197
# 85    BAH 2018-01-02        37.96      488675.0 2017-01-03    35.203982
# 86    ATU 2018-01-02        25.05      912860.0 2017-01-03    26.708350
# 87   ATRO 2018-01-02        42.27      127527.0 2017-01-03    34.000000
# 88    ATO 2018-01-02        85.04      668765.0 2017-01-03    73.331112
# 89   ATLO 2018-01-02        28.10        7850.0 2017-01-03    32.131939
# 90    APH 2018-01-02        87.80     1227122.0 2017-01-03    66.983896
# 91    ANH 2018-01-02         5.37      839578.0 2017-01-03     4.866323
# 92    ALB 2018-01-02       131.53     1117717.0 2017-01-03    87.310827
# 93    AKR 2018-01-02        27.75      553012.0 2017-01-03    31.753996
# 94    AEE 2018-01-02        58.39     1189242.0 2017-01-03    51.172942
# 95    ADM 2018-01-02        40.09     3649242.0 2017-01-03    44.798018
# 96   ACRE 2018-01-02        12.79      164627.0 2017-01-03    13.255966
# 97    ACN 2018-01-02       153.84     2854628.0 2017-01-03   114.153742
# 98    ABT 2018-01-02        58.79    10112783.0 2017-01-03    38.170443
# 99    ABM 2018-01-02        37.75      653235.0 2017-01-03    40.312951
#
#     adj_volume_y
# 0   1.105063e+06
# 1   1.434366e+06
# 2   2.075390e+05
# 3   1.556510e+05
# 4   2.980780e+05
# 5   5.173040e+05
# 6   5.203000e+03
# 7   7.075230e+05
# 8   7.239020e+05
# 9   1.105134e+07
# 10  1.973258e+06
# 11  7.268680e+05
# 12  3.305600e+04
# 13  6.300990e+05
# 14  1.656260e+05
# 15  1.256370e+05
# 16  9.132800e+04
# 17  6.619286e+03
# 18  9.439195e+06
# 19  2.660933e+06
# 20  2.560315e+06
# 21  1.937513e+06
# 22  8.666260e+05
# 23  1.578206e+06
# 24  1.404470e+05
# 25  1.305490e+05
# 26  2.553100e+05
# 27  9.086900e+04
# 28  7.022870e+05
# 29  4.849140e+05
# ..           ...
# 70  1.085110e+05
# 71  4.545100e+04
# 72  3.706410e+05
# 73  1.000242e+06
# 74  6.359490e+05
# 75  4.051809e+06
# 76  3.450973e+06
# 77  2.252200e+04
# 78  3.553848e+06
# 79  1.024630e+05
# 80  5.934780e+05
# 81  2.197020e+05
# 82  2.665550e+05
# 83  1.141010e+05
# 84  2.971410e+05
# 85  1.788875e+06
# 86  1.038151e+06
# 87  9.465300e+04
# 88  4.515270e+05
# 89  3.407000e+03
# 90  8.266110e+05
# 91  8.379980e+05
# 92  9.755940e+05
# 93  6.367000e+05
# 94  1.107195e+06
# 95  3.614876e+06
# 96  1.472830e+05
# 97  2.352157e+06
# 98  9.677316e+06
# 99  5.486920e+05
#
# [100 rows x 7 columns]

# %%
stockclusterdf=pd.merge(stockdf, dfgg, left_on='ticker', right_on=0)

# %%
stockclusterdf
# Out:
#    ticker     date_x  adj_close_x  adj_volume_x     date_y  adj_close_y  \
# 0     TAP 2018-01-02        82.24     1129690.0 2017-01-03    96.625645
# 1      RL 2018-01-02       104.88     1119979.0 2017-01-03    88.972387
# 2    PRIM 2018-01-02        27.48      135477.0 2017-01-03    23.021564
# 3    PRGS 2018-01-02        43.24      451038.0 2017-01-03    31.658182
# 4     PRA 2018-01-02        55.85      216274.0 2017-01-03    55.111216
# 5     PNW 2018-01-02        83.89      697495.0 2017-01-03    74.916485
# 6    PLPC 2018-01-02        72.40       10158.0 2017-01-03    57.220523
# 7     PEI 2018-01-02        12.47     1836336.0 2017-01-03    18.333045
# 8    PACW 2018-01-02        50.44     1178150.0 2017-01-03    52.865970
# 9    ORCL 2018-01-02        46.63    25309088.0 2017-01-03    38.090088
# 10      O 2018-01-02        56.62     1616390.0 2017-01-03    55.419014
# 11   NPTN 2018-01-02         7.18      977908.0 2017-01-03    10.890000
# 12    NEU 2018-01-02       403.63       63687.0 2017-01-03   423.747414
# 13    NAV 2018-01-02        43.63      382189.0 2017-01-03    31.840000
# 14   NANO 2018-01-02        25.25      193078.0 2017-01-03    24.950000
# 15   MTRX 2018-01-02        18.30      208983.0 2017-01-03    23.000000
# 16   MTRN 2018-01-02        50.00      366626.0 2017-01-03    39.658540
# 17   MRIN 2018-01-02        10.90        4139.0 2017-01-03    16.800000
# 18    MGM 2018-01-02        33.51     5446404.0 2017-01-03    29.159559
# 19    MAS 2018-01-02        43.81     1579123.0 2017-01-03    31.866486
# 20    LYB 2018-01-02       112.23     1113175.0 2017-01-03    84.295272
# 21   LRCX 2018-01-02       189.28     2009499.0 2017-01-03   105.982490
# 22    LNT 2018-01-02        42.11     1392947.0 2017-01-03    36.756680
# 23    LNC 2018-01-02        77.91     1294623.0 2017-01-03    65.799744
# 24   LMNX 2018-01-02        20.33      234566.0 2017-01-03    20.212443
# 25   LION 2018-01-02        21.85       75802.0 2017-01-03    23.213722
# 26   LGND 2018-01-02       138.63      127824.0 2017-01-03   102.500000
# 27   LANC 2018-01-02       128.71      117327.0 2017-01-03   139.824918
# 28   IRET 2018-01-02         5.69      632353.0 2017-01-03     6.923718
# 29   IRBT 2018-01-02        80.10      792566.0 2017-01-03    57.580000
# ..    ...        ...          ...           ...        ...          ...
# 70   CMCO 2018-01-02        41.15      122219.0 2017-01-03    27.322472
# 71    CLW 2018-01-02        46.20       56175.0 2017-01-03    66.550000
# 72   CHSP 2018-01-02        27.53      476219.0 2017-01-03    24.973745
# 73    CFX 2018-01-02        39.82      556633.0 2017-01-03    36.900000
# 74   CERS 2018-01-02         3.56      489322.0 2017-01-03     4.330000
# 75   CELG 2018-01-02       106.16     4724190.0 2017-01-03   118.750000
# 76    CCL 2018-01-02        66.75     2783766.0 2017-01-03    51.178923
# 77    CCF 2018-01-02       120.05       22930.0 2017-01-03    85.650000
# 78    CBS 2018-01-02        59.17     3177625.0 2017-01-03    63.841668
# 79   BUSE 2018-01-02        29.88      142211.0 2017-01-03    30.070442
# 80   BRKR 2018-01-02        34.52      313000.0 2017-01-03    21.482699
# 81   BOKF 2018-01-02        92.35      133073.0 2017-01-03    80.534127
# 82    BOH 2018-01-02        85.82      231924.0 2017-01-03    87.034406
# 83   BBOX 2018-01-02         3.50      293039.0 2017-01-03    14.875725
# 84   BANR 2018-01-02        55.17      150027.0 2017-01-03    54.366197
# 85    BAH 2018-01-02        37.96      488675.0 2017-01-03    35.203982
# 86    ATU 2018-01-02        25.05      912860.0 2017-01-03    26.708350
# 87   ATRO 2018-01-02        42.27      127527.0 2017-01-03    34.000000
# 88    ATO 2018-01-02        85.04      668765.0 2017-01-03    73.331112
# 89   ATLO 2018-01-02        28.10        7850.0 2017-01-03    32.131939
# 90    APH 2018-01-02        87.80     1227122.0 2017-01-03    66.983896
# 91    ANH 2018-01-02         5.37      839578.0 2017-01-03     4.866323
# 92    ALB 2018-01-02       131.53     1117717.0 2017-01-03    87.310827
# 93    AKR 2018-01-02        27.75      553012.0 2017-01-03    31.753996
# 94    AEE 2018-01-02        58.39     1189242.0 2017-01-03    51.172942
# 95    ADM 2018-01-02        40.09     3649242.0 2017-01-03    44.798018
# 96   ACRE 2018-01-02        12.79      164627.0 2017-01-03    13.255966
# 97    ACN 2018-01-02       153.84     2854628.0 2017-01-03   114.153742
# 98    ABT 2018-01-02        58.79    10112783.0 2017-01-03    38.170443
# 99    ABM 2018-01-02        37.75      653235.0 2017-01-03    40.312951
#
#     adj_volume_y     0                                  companyname cluster
# 0   1.105063e+06   TAP               [Molson Coors Brewing Company]    [28]
# 1   1.434366e+06    RL                   [Ralph Lauren Corporation]     [5]
# 2   2.075390e+05  PRIM              [Primoris Services Corporation]     [0]
# 3   1.556510e+05  PRGS              [Progress Software Corporation]    [17]
# 4   2.980780e+05   PRA                   [ProAssurance Corporation]     [9]
# 5   5.173040e+05   PNW          [Pinnacle West Capital Corporation]     [3]
# 6   5.203000e+03  PLPC            [Preformed Line Products Company]     [7]
# 7   7.075230e+05   PEI  [Pennsylvania Real Estate Investment Trust]     [2]
# 8   7.239020e+05  PACW                            [PacWest Bancorp]     [4]
# 9   1.105134e+07  ORCL                         [Oracle Corporation]     [8]
# 10  1.973258e+06     O                  [Realty Income Corporation]     [2]
# 11  7.268680e+05  NPTN                   [NeoPhotonics Corporation]    [24]
# 12  3.305600e+04   NEU                      [NewMarket Corporation]    [28]
# 13  6.300990e+05   NAV         [Navistar International Corporation]    [28]
# 14  1.656260e+05  NANO                   [Nanometrics Incorporated]    [24]
# 15  1.256370e+05  MTRX                     [Matrix Service Company]     [0]
# 16  9.132800e+04  MTRN                       [Materion Corporation]     [3]
# 17  6.619286e+03  MRIN                [Marin Software Incorporated]    [17]
# 18  9.439195e+06   MGM                  [MGM Resorts International]    [13]
# 19  2.660933e+06   MAS                          [Masco Corporation]    [28]
# 20  2.560315e+06   LYB               [LyondellBasell Industries NV]     [8]
# 21  1.937513e+06  LRCX                   [Lam Research Corporation]    [24]
# 22  8.666260e+05   LNT                 [Alliant Energy Corporation]     [0]
# 23  1.578206e+06   LNC               [Lincoln National Corporation]    [27]
# 24  1.404470e+05  LMNX                        [Luminex Corporation]    [10]
# 25  1.305490e+05  LION              [Fidelity Southern Corporation]     [4]
# 26  2.553100e+05  LGND        [Ligand Pharmaceuticals Incorporated]     [6]
# 27  9.086900e+04  LANC               [Lancaster Colony Corporation]    [28]
# 28  7.022870e+05  IRET                [Investors Real Estate Trust]     [2]
# 29  4.849140e+05  IRBT                         [iRobot Corporation]    [28]
# ..           ...   ...                                          ...     ...
# 70  1.085110e+05  CMCO              [Columbus McKinnon Corporation]    [28]
# 71  4.545100e+04   CLW               [Clearwater Paper Corporation]    [28]
# 72  3.706410e+05  CHSP                   [Chesapeake Lodging Trust]    [15]
# 73  1.000242e+06   CFX                         [Colfax Corporation]    [28]
# 74  6.359490e+05  CERS                          [Cerus Corporation]     [6]
# 75  4.051809e+06  CELG                        [Celgene Corporation]    [10]
# 76  3.450973e+06   CCL                       [Carnival Corporation]     [3]
# 77  2.252200e+04   CCF                          [Chase Corporation]    [28]
# 78  3.553848e+06   CBS                            [CBS Corporation]     [7]
# 79  1.024630e+05  BUSE                    [First Busey Corporation]     [7]
# 80  5.934780e+05  BRKR                         [Bruker Corporation]     [8]
# 81  2.197020e+05  BOKF                  [BOK Financial Corporation]     [3]
# 82  2.665550e+05   BOH                 [Bank of Hawaii Corporation]     [4]
# 83  1.141010e+05  BBOX                      [Black Box Corporation]    [14]
# 84  2.971410e+05  BANR                         [Banner Corporation]     [4]
# 85  1.788875e+06   BAH    [Booz Allen Hamilton Holding Corporation]    [26]
# 86  1.038151e+06   ATU                        [Actuant Corporation]    [28]
# 87  9.465300e+04  ATRO                      [Astronics Corporation]    [26]
# 88  4.515270e+05   ATO                   [Atmos Energy Corporation]    [28]
# 89  3.407000e+03  ATLO                  [Ames National Corporation]     [4]
# 90  8.266110e+05   APH                       [Amphenol Corporation]     [7]
# 91  8.379980e+05   ANH         [Anworth Mortgage Asset Corporation]    [22]
# 92  9.755940e+05   ALB                      [Albemarle Corporation]    [28]
# 93  6.367000e+05   AKR                        [Acadia Realty Trust]     [2]
# 94  1.107195e+06   AEE                         [Ameren Corporation]     [3]
# 95  3.614876e+06   ADM             [Archer Daniels Midland Company]     [7]
# 96  1.472830e+05  ACRE    [Ares Commercial Real Estate Corporation]    [22]
# 97  2.352157e+06   ACN                              [Accenture plc]    [14]
# 98  9.677316e+06   ABT                        [Abbott Laboratories]     [3]
# 99  5.486920e+05   ABM                [ABM Industries Incorporated]    [14]
#
# [100 rows x 10 columns]

# %%
stockclusterdf.to_csv("Stockclusteroutput.csv", index=True)

# %%
import matplotlib.pyplot as plt   # Import matplotlib
# This line is necessary for the plot to appear in a Jupyter notebook
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots
 
# apple["Adj. Close"].plot(grid = True) # Plot the adjusted closing price of AAPL
# apple["Adj. Open"].plot(grid = True) # Plot the adjusted open price of AAPL
google ["Adj. Open"].plot(grid = True) # Plot the adjusted open price of AAPL
apple ["Adj. Open"].plot(grid = True) # Plot the adjusted open price of AAPL

# %%
microsoft, google = (quandl.get("WIKI/" + s, start_date=start, end_date=end) for s in ["MSFT", "GOOG",'AAPL'])
 
# Below I create a DataFrame consisting of the adjusted closing price of these stocks, first by making a list of these objects and using the join method
stocks = pd.DataFrame({"AAPL": apple["Adj. Close"],
                      "MSFT": microsoft["Adj. Close"],
                      "GOOG": google["Adj. Close"]})
 
stocks.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-383-d7638ae32560> in <module>()
# ----> 1 microsoft, google = (quandl.get("WIKI/" + s, start_date=start, end_date=end) for s in ["MSFT", "GOOG",'AAPL'])
#       2
#       3 # Below I create a DataFrame consisting of the adjusted closing price of these stocks, first by making a list of these objects and using the join method
#       4 stocks = pd.DataFrame({"AAPL": apple["Adj. Close"],
#       5                       "MSFT": microsoft["Adj. Close"],
#
# ValueError: too many values to unpack (expected 2)

# %%
stocks.plot(grid = True)

# %%
stocks.plot(secondary_y = ["AAPL", "MSFT"], grid = True)

# %%
# python
# df.apply(arg) will apply the function arg to each column in df, and return a DataFrame with the result
# Recall that lambda x is an anonymous function accepting parameter x; in this case, x will be a pandas Series object
stock_return = stocks.apply(lambda x: x / x[0])
stock_return.head() - 1

# %%
stock_return.plot(grid = True).axhline(y = 1, color = "black", lw = 2)

# %%
# Let's use NumPy's log function, though math's log function would work just as well
import numpy as np
 
stock_change = stocks.apply(lambda x: np.log(x) - np.log(x.shift(1))) # shift moves dates back by 1.
stock_change.head()

# %%
stock_change.plot(grid = True).axhline(y = 0, color = "black", lw = 2)

# %%
# #import pandas_datareader.data as web    # Going to get SPY from Yahoo! (I know I said you shouldn't but I didn't have a choice)
# #spyder = web.DataReader("SPY", "yahoo", start, end)    # Didn't work
# #spyder = web.DataReader("SPY", "google", start, end)    # Didn't work either
# # If all else fails, read from a file, obtained from here: http://www.nasdaq.com/symbol/spy/historical
# spyderdat = pd.read_csv("/home/curtis/Downloads/HistoricalQuotes.csv")    # Obviously specific to my system; set to
#                                                                           # location on your machine
# spyderdat = pd.DataFrame(spyderdat.loc[:, ["open", "high", "low", "close", "close"]].iloc[1:].as_matrix(),
#                          index=pd.DatetimeIndex(spyderdat.iloc[1:, 0]),
#                          columns=["Open", "High", "Low", "Close", "Adj Close"]).sort_index()
 
# spyder = spyderdat.loc[start:end]
 
# stocks = stocks.join(spyder.loc[:, "Adj Close"]).rename(columns={"Adj Close": "SPY"})
# stocks.head()

# %%
from matplotlib.dates import DateFormatter, WeekdayLocator,\
    DayLocator, MONDAY
from mpl_finance import candlestick_ohlc
 
def pandas_candlestick_ohlc(dat, stick = "day", adj = False, otherseries = None):
    """
    :param dat: pandas DataFrame object with datetime64 index, and float columns "Open", "High", "Low", and "Close", likely created via DataReader from "yahoo"
    :param stick: A string or number indicating the period of time covered by a single candlestick. Valid string inputs include "day", "week", "month", and "year", ("day" default), and any numeric input indicates the number of trading days included in a period
    :param adj: A boolean indicating whether to use adjusted prices
    :param otherseries: An iterable that will be coerced into a list, containing the columns of dat that hold other series to be plotted as lines
 
    This will show a Japanese candlestick plot for stock data stored in dat, also plotting other series if passed.
    """
    mondays = WeekdayLocator(MONDAY)        # major ticks on the mondays
    alldays = DayLocator()              # minor ticks on the days
    dayFormatter = DateFormatter('%d')      # e.g., 12
 
    # Create a new DataFrame which includes OHLC data for each period specified by stick input
    fields = ["Open", "High", "Low", "Close"]
    if adj:
        fields = ["Adj. " + s for s in fields]
    transdat = dat.loc[:,fields]
    transdat.columns = pd.Index(["Open", "High", "Low", "Close"])
    if (type(stick) == str):
        if stick == "day":
            plotdat = transdat
            stick = 1 # Used for plotting
        elif stick in ["week", "month", "year"]:
            if stick == "week":
                transdat["week"] = pd.to_datetime(transdat.index).map(lambda x: x.isocalendar()[1]) # Identify weeks
            elif stick == "month":
                transdat["month"] = pd.to_datetime(transdat.index).map(lambda x: x.month) # Identify months
            transdat["year"] = pd.to_datetime(transdat.index).map(lambda x: x.isocalendar()[0]) # Identify years
            grouped = transdat.groupby(list(set(["year",stick]))) # Group by year and other appropriate variable
            plotdat = pd.DataFrame({"Open": [], "High": [], "Low": [], "Close": []}) # Create empty data frame containing what will be plotted
            for name, group in grouped:
                plotdat = plotdat.append(pd.DataFrame({"Open": group.iloc[0,0],
                                            "High": max(group.High),
                                            "Low": min(group.Low),
                                            "Close": group.iloc[-1,3]},
                                           index = [group.index[0]]))
            if stick == "week": stick = 5
            elif stick == "month": stick = 30
            elif stick == "year": stick = 365
 
    elif (type(stick) == int and stick >= 1):
        transdat["stick"] = [np.floor(i / stick) for i in range(len(transdat.index))]
        grouped = transdat.groupby("stick")
        plotdat = pd.DataFrame({"Open": [], "High": [], "Low": [], "Close": []}) # Create empty data frame containing what will be plotted
        for name, group in grouped:
            plotdat = plotdat.append(pd.DataFrame({"Open": group.iloc[0,0],
                                        "High": max(group.High),
                                        "Low": min(group.Low),
                                        "Close": group.iloc[-1,3]},
                                       index = [group.index[0]]))
 
    else:
        raise ValueError('Valid inputs to argument "stick" include the strings "day", "week", "month", "year", or a positive integer')
 
 
    # Set plot parameters, including the axis object ax used for plotting
    fig, ax = plt.subplots()
    fig.subplots_adjust(bottom=0.2)
    if plotdat.index[-1] - plotdat.index[0] < pd.Timedelta('200 days'):
        weekFormatter = DateFormatter('%b %d')  # e.g., Jan 12
        ax.xaxis.set_major_locator(mondays)
        ax.xaxis.set_minor_locator(alldays)
    else:
        weekFormatter = DateFormatter('%b %d, %Y')
    ax.xaxis.set_major_formatter(weekFormatter)
 
    ax.grid(True)
 
    # Create the candelstick chart
    candlestick_ohlc(ax, list(zip(list(date2num(plotdat.index.tolist())), plotdat["Open"].tolist(), plotdat["High"].tolist(),
                      plotdat["Low"].tolist(), plotdat["Close"].tolist())),
                      colorup = "black", colordown = "red", width = stick * .4)
 
    # Plot other series (such as moving averages) as lines
    if otherseries != None:
        if type(otherseries) != list:
            otherseries = [otherseries]
        dat.loc[:,otherseries].plot(ax = ax, lw = 1.3, grid = True)
 
    ax.xaxis_date()
    ax.autoscale_view()
    plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
 
    plt.show()
 
pandas_candlestick_ohlc(apple, adj=True, stick="month")

# %%
apple["20d"] = np.round(apple["Adj. Close"].rolling(window = 20, center = False).mean(), 2)
pandas_candlestick_ohlc(apple.loc['2018-01-04':'2018-12-31',:], otherseries = "20d", adj=True)

# %%
start = datetime.datetime(2018,1,1)
apple = quandl.get("WIKI/AAPL", start_date=start, end_date=end)
apple["20d"] = np.round(apple["Adj. Close"].rolling(window = 20, center = False).mean(), 2)
 
pandas_candlestick_ohlc(apple.loc['2018-01-04':'2018-12-31',:], otherseries = "20d", adj=True)

# %%
apple["50d"] = np.round(apple["Adj. Close"].rolling(window = 50, center = False).mean(), 2)
apple["200d"] = np.round(apple["Adj. Close"].rolling(window = 200, center = False).mean(), 2)
 
pandas_candlestick_ohlc(apple.loc['2018-01-04':'2018-12-31',:], otherseries = ["20d", "50d", "200d"], adj=True)

# %%
apple['20d-50d'] = apple['20d'] - apple['50d']
apple.tail()
